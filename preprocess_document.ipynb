# %%
import time
import sqlite3
import json
import requests

import pandas as pd

# %%
storage_df = pd.read_csv("documents.csv")

used_df = storage_df[~storage_df['url'].isnull()]
used_df
# Out:
#                                                    name  \
# 0     👑 Bộ đề luyện thi thử VIP - Đánh giá năng lực ...
# 1     Gói đề luyện thi Đánh Giá Năng Lực ĐHQG Hà Nội...
# 2     Gói đề luyện thi Đánh Giá Năng Lực ĐHQG Hà Nội...
# 3     Gói đề luyện thi Đánh Giá Năng Lực ĐHQG Hà Nội...
# 4     Gói đề luyện thi Đánh Giá Năng Lực ĐHQG Hà Nội...
# ...                                                 ...
# 2756  KHBD GIÁO ÁN WORD CHÍNH KHÓA – GIÁO DỤC THỂ CH...
# 2760     Giáo án quốc phòng an ninh 12 kết nối tri thức
# 2761  Giáo án powerpoint quốc phòng an ninh 12 kết n...
# 2762            Giáo án quốc phòng an ninh 12 cánh diều
# 2763  Giáo án powerpoint quốc phòng an ninh 12 cánh ...
#
#                              type                  category   price  datakey  \
# 0     dai-hoc-quoc-gia-ha-noi-hsa  danh-gia-nang-luc-tu-duy  899000    27547
# 1     dai-hoc-quoc-gia-ha-noi-hsa  danh-gia-nang-luc-tu-duy  699000    26420
# 2     dai-hoc-quoc-gia-ha-noi-hsa  danh-gia-nang-luc-tu-duy  699000    26419
# 3     dai-hoc-quoc-gia-ha-noi-hsa  danh-gia-nang-luc-tu-duy  499000    26418
# 4     dai-hoc-quoc-gia-ha-noi-hsa  danh-gia-nang-luc-tu-duy  499000    26417
# ...                           ...                       ...     ...      ...
# 2756          giao-duc-the-chat-5         giao-duc-the-chat  299000    21170
# 2760        quoc-phong-an-ninh-12     quoc-phong-va-an-ninh  299000    22378
# 2761        quoc-phong-an-ninh-12     quoc-phong-va-an-ninh  299000    22377
# 2762        quoc-phong-an-ninh-12     quoc-phong-va-an-ninh  299000    22374
# 2763        quoc-phong-an-ninh-12     quoc-phong-va-an-ninh  299000    22373
#
#                                                     url
# 0     https://drive.google.com/drive/u/0/folders/1eJ...
# 1     https://drive.google.com/open?id=1qIO1ugFDJLE4...
# 2     https://drive.google.com/open?id=1j-MqivmMYbNV...
# 3     https://drive.google.com/open?id=1ZTXVDSPSoL-Q...
# 4     https://drive.google.com/open?id=1vTXTmmL4MdxS...
# ...                                                 ...
# 2756  https://drive.google.com/drive/folders/1RkibR2...
# 2760  https://drive.google.com/open?id=1ekIohw8LHJRj...
# 2761  https://drive.google.com/open?id=14M_Pd3J4oUG5...
# 2762  https://drive.google.com/open?id=1zxfpQNHykXdj...
# 2763  https://drive.google.com/open?id=1fGgsq8nVOUfk...
#
# [2504 rows x 6 columns]

# %%
used_df.to_csv("Storage.csv")
